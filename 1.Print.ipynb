# %%
print("Hello World")
# Out:
# Hello World

# %%
print(123)
# Out:
# 123

# %%
Print("hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("hi")
#
# NameError: name 'Print' is not defined
