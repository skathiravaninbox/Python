# %%
def addtion():
    add=a+b
    print(add)
    #return add

# %%
a=int(input("Enter a value"))
b=int(input("Enter b value"))
adda=addtion()
print(adda)
# Out:
# Enter a value 30
# Enter b value 20
# 50
# None

# %%
def agecategory():
    if(age<18):
        print("Children")
        cate="Children"
    elif(age<35):
        print("Adult")
        cate="Adult"
    elif(age<59):
        print("Citizen")
        cate="Citizen"
    else:
        print("Senior Citizen")
        cate="Senior Citizen"

# %%
age=int(input("Enter your age"))
agecat=agecategory()
# Out:
# Enter your age 45
# Citizen

# %%
age=int(input("Enter your age"))
agecat2=agecategory()
# Out:
# Enter your age 75
# Senior Citizen

# %%
def oddEven():
    num=int(input("Enter a value"))
    if((num%2)==0):
        print("Even")
        msg="Even"
    else:
        print("Odd")
        msg="Odd"
    return msg

# %%
oddEven()
# Out:
# Enter a value 4
# 4  is even
# 'Even Number'

# %%
#one function result output is another function input
message=oddEven()
if(message=='Even'):
    print("The answer is Even")
else:
    print("The answer is Odd")
# Out:
# Enter a value 5
# Odd
# The answer is Odd

# %%
def BMI():
    bmi=int(input("Enter the int value BMI Index: "))
    if(bmi<17):
        print("You are Serverly Underweight")
        message="Serverly Underweight"
    elif(bmi<19):
        print("You are Underweight")
        message="Underweight"
    elif(bmi<26):
        print("You are Healthy")
        message="Healthy"
    elif(bmi<31):
        print("You are Overweight")
        message="Overweight"
    else:
        print("You are Serverly Overweight")
        message="Serverly Overweight"
    return message

# %%
bmi=BMI()
# Out:
# Enter the int value BMI Index:  34
# You are Serverly Overweight

# %%
bmi
# Out:
# 'Serverly Overweight'

# %%
def add(num1,num2):
    return num1+num2

# %%
add(5,5)
# Out:
# 10

# %%
res=add(3,4)

# %%
res
# Out:
# 7
