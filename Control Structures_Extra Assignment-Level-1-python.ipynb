# %%
#print Statement

print("Hope AI")
# Out:
# Hope AI

# %% [raw]
# # Buy input

# %%
ins=input("Enter your Institution Name: ")
print("Your Instution Name is ",ins)
# Out:
# Enter your Institution Name:  Hope AI
# Your Instution Name is  Hope AI

# %%
#Buy inputs
name=input("Enter your Name: ")
age=input("Enter your Age: ")
school=input("Enter your School: ")
degree=input("Enter your Degree: ")
print("The details ")
print("*****************************")
print("Name : ",name)
print("Age : ",name)
print("School : ",name)
print("Degree : ",name)
# Out:
# Enter your Name:  kathir
# Enter your Age:  35
# Enter your School:  Govt Hr Sec School
# Enter your Degree:  MCA
# The details
# *****************************
# Name :  kathir
# Age :  kathir
# School :  kathir
# Degree :  kathir

# %%
#Addition
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Addtion of  Number1 and Number2 is ",num1+num2)
# Out:
# Enter Number1 value  167
# Enter Number2 value  890
# The Addtion of  Number1 and Number2 is  1057

# %%
#Subtraction
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Subtraction of  Number1 and Number2 is ",num1-num2)
# Out:
# Enter Number1 value  145
# Enter Number2 value  38
# The Subtraction of  Number1 and Number2 is  107

# %%
#Multiplication
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Multiplication of  Number1 and Number2 is ",num1*num2)
# Out:
# Enter Number1 value  13
# Enter Number2 value  4
# The Multiplication of  Number1 and Number2 is  52

# %%
#Division
num1=float(input("Enter Number1 value "))
num2=float(input("Enter Number2 value "))
print("The Division of  Number1 and Number2 is ",num1/num2)
# Out:
# Enter Number1 value  32
# Enter Number2 value  23
# The Division of  Number1 and Number2 is  1.391304347826087

# %%
#Floor division
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Floor Division of  Number1 and Number2 is ",num1//num2)
# Out:
# Enter Number1 value  76
# Enter Number2 value  31
# The Floor Division of  Number1 and Number2 is  2

# %%
#Modulo
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Modulo of  Number1 and Number2 is ", num1%num2)
# Out:
# Enter Number1 value  76
# Enter Number2 value  31
# The Modulo of  Number1 and Number2 is  14

# %%
#Power
num1=int(input("Enter Number1 value "))
num2=int(input("Enter Number2 value "))
print("The Number1 power of Number2 is ", num1**num2)
# Out:
# Enter Number1 value  4
# Enter Number2 value  4
# The Number1 power of Number2 is  256
